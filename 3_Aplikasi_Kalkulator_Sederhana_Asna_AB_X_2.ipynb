# %% [markdown]
# <a href="https://colab.research.google.com/github/asnaa01/KKA-X-Semester-1-AsnaAlBadii/blob/main/3_Aplikasi_Kalkulator_Sederhana_Asna_AB_X_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Menghitung Luas Persegi Panjang

# %%
panjang = int(input("Masukkan panjang dari persegi panjang (cm): "))
lebar = int(input("Masukkan lebar dari persegi panjang (cm): "))

luas = panjang * lebar

print(f"\nLuas dari persegi panjang yaitu {luas} cm^2")
# Out:
# Masukkan panjang dari persegi panjang (cm): 5
# Masukkan lebar dari persegi panjang (cm): 4
#
# Luas dari persegi panjang yaitu 20 cm^2

# %% [markdown]
# #Menghitung Volume Bola

# %%
jari_jari = int(input("Masukkan jari_jari dari bola (cm): "))

volume = 4/3 * 22/7 * jari_jari**3

print(f"\nVolume dari bola yaitu {volume} cm^3")
# Out:
# Masukkan jari_jari dari bola (cm): 24
#
# Volume dari bola yaitu 57929.14285714286 cm^3
