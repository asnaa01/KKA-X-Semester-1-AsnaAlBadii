# %% [markdown]
# <a href="https://colab.research.google.com/github/asnaa01/KKA-X-Semester-1-AsnaAlBadii/blob/main/2_Tipe_Variabel_Asna_A_X_2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Asna Al Badi'i
#
#
# Kelas : X.2
#
#
# No. absen : 04

# %% [markdown]
# #Konsep Dasar Variabel

# %%
print("asnaalbadii.2025@gmail.com")
print("asnaalbadii.2025@gmail.com")
print("asnaalbadii.2025@gmail.com")
# Out:
# asnaalbadii.2025@gmail.com
# asnaalbadii.2025@gmail.com
# asnaalbadii.2025@gmail.com

# %%
email_user = "asnaalbadii.2025@gmail.com"
print(email_user)
print(email_user)
print(email_user)
# Out:
# asnaalbadii.2025@gmail.com
# asnaalbadii.2025@gmail.com
# asnaalbadii.2025@gmail.com

# %% [markdown]
# #Peraturan Penulisan Variabel

# %%
#Hanya boleh menggunakan huruf, angka, dan underscore
harga telur = 15.000
print = (harga telur)
# Out:
#   File "/tmp/ipython-input-1107174329.py", line 2
#     harga telur = 15.000
#           ^
# SyntaxError: invalid syntax

# %%
hargatelur = 15000
print(hargatelur)
# Out:
# 15000

# %%
#Tidak boleh diawali oleh angka
1_nama_siswa = "Ahmad Dhani"

print(1_nama_siswa)
# Out:
#   File "/tmp/ipython-input-2837710343.py", line 2
#     1_nama_siswa = "Ahmad Dhani"
#      ^
# SyntaxError: invalid decimal literal

# %%
#Tidak boleh menggunakan kata kunci python
if = "Handayani"

print(if)
# Out:
#   File "/tmp/ipython-input-3190473001.py", line 2
#     if = "Handayani"
#        ^
# SyntaxError: invalid syntax

# %%
If = "Handayani"

print (If)
# Out:
# Handayani

# %%
print = "Noor"

print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4169316329.py in <cell line: 0>()
#       1 print = "Noor"
#       2
# ----> 3 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print = "Noor"
print(Print)
# Out:
# Noor

# %%
#Sensitif terhadap penulisan kapital

USIA = 17

print(Usia)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1092909732.py in <cell line: 0>()
#       3 USIA = 17
#       4
# ----> 5 print(Usia)
#
# NameError: name 'Usia' is not defined

# %%
print(USIA)
# Out:
# 17

# %%
_ = "Fazel Wardana"

# %%
_ = "Lia Wati"

# %%
print(_)
# Out:
# Lia Wati

# %% [markdown]
# #Assignment

# %%
#Single Assignment
bb_fazel = 50
bb_dani = 60

print(bb_dani)
print(bb_fazel)
# Out:
# 60
# 50

# %%
#Multiple Assignment
bb_fazel,bb_dani = 55, 60
print(bb_dani)
print(bb_fazel)
# Out:
# 60
# 55

# %%
bb_fazel, bb_dani = 55, 60, 70
print(bb_dani)
print(bb_fazel)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-512873506.py in <cell line: 0>()
# ----> 1 bb_fazel, bb_dani = 55, 60, 70
#       2 print(bb_dani)
#       3 print(bb_fazel)
#
# ValueError: too many values to unpack (expected 2)

# %%
nama_siswa_1, nama_siswa_2 = "deni", "doni"
print(nama_siswa_1)
print(nama_siswa_2)
# Out:
# deni
# doni

# %%
bb_fazel, bb_dani, bb_adli = 55, 60
print(bb_dani)
print(bb_fazel)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2588918596.py in <cell line: 0>()
# ----> 1 bb_fazel, bb_dani, bb_adli = 55, 60
#       2 print(bb_dani)
#       3 print(bb_fazel)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
#Chain Assignment
bb_hasbi = bb_dani = 60

print(bb_hasbi)
print(bb_dani)
# Out:
# 60
# 60

# %% [markdown]
# #Cara Penulisan Operator pada Phyton

# %%
#Tanpa Variabel
print(9+6)
# Out:
# 15

# %%
print("shinta")
# Out:
# shinta

# %%
print("9+6")
# Out:
# 9+6

# %%
#Operan Disimpan Ke Variabel
jumlah_hp_habibi = 10
jumlah_hp_syauqi = 6

print(jumlah_hp_habibi + jumlah_hp_syauqi)
# Out:
# 16

# %%
#Hasil Operasi Disimpan Ke Variabel
total_hp = 16

print(total_hp)
# Out:
# 16

# %%
#Operand dan Hasil Operasi Disimpan Ke Variabel
jumlah_hp_habibi = 10
jumlah_hp_syauqi = 6

total_hp = jumlah_hp_habibi + jumlah_hp_syauqi
print(total_hp)
# Out:
# 16

# %% [markdown]
# #Latihan Soal Assignment

# %%
nama = "Andi"
print(nama)
# Out:
# Andi

# %%
Nama, Umur, Kelas = "Budi", 15,"9A"

print(Nama, Umur, Kelas)
# Out:
# Budi 15 9A

# %%
Berat_Andi = Berat_Siti = Berat_Eko = 45.5
print(Berat_Andi, Berat_Siti, Berat_Eko)
# Out:
# 45.5 45.5 45.5

# %% [markdown]
# Soal

# %%
print(24 * 3)
# Out:
# 72

# %%
Total_jumlah_botol = 24*3
print(Total_jumlah_botol)
# Out:
# 72

# %%
Banyak_botol_per_kardus = 24
Jumlah_kardus = 3
ce
print(Banyak_botol_per_kardus*Jumlah_kardus)
# Out:
# 72

# %%
Banyak_botol_per_kardus = 24
Jumlah_kardus = 3
Total_jumlah_botol = Banyak_botol_per_kardus*Jumlah_kardus
print(Total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #Jenis - jenis Tipe Variabel

# %%
a = "Faris"
print(a)
type(a)
# Out:
# Faris
# str

# %%
b = 9.9
print(b)
type(b)
# Out:
# 9.9
# float

# %%
c = 0
print(c)
type(c)
# Out:
# 0
# int

# %%
d = true
print(d)
type(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3650036183.py in <cell line: 0>()
# ----> 1 d = true
#       2 print(d)
#       3 type(d)
#
# NameError: name 'true' is not defined

# %%
d = True
print(d)
type(d)
# Out:
# True
# bool

# %%
f = "False"
print(f)
type(f)
# Out:
# False
# str

# %%
g = 9,2
print(g)
type(g)
# Out:
# (9, 2)
# tuple

# %%
type("Rendra")
# Out:
# str

# %%
type(-9.1)
# Out:
# float

# %% [markdown]
# #Mengubah Bentuk Variabel

# %%
a = 5
print(a)
type(a)
# Out:
# 5
# int

# %%
a = float(a)
print(a)
type(a)
# Out:
# 5.0
# float

# %%
b = bool(2)
print(b)
type(b)
# Out:
# True
# bool

# %% [markdown]
# #Operator Perbandingan

# %%
print(6 >= 6)
# Out:
# True

# %%
print(8 == 9)
# Out:
# False

# %%
print(8 != 9)
# Out:
# True

# %%
print(8 < 10)
# Out:
# True

# %%
print(8 > 10)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print(not(5 >= 5))
# Out:
# False

# %%
print(8>7 and 6<5)
# Out:
# False

# %%
print(7 <= 1 or 2 != 2)
# Out:
# False

# %%
print(not(0 == 1 and 1 != 1))
# Out:
# True

# %%
print(not(5 < 10 or 5 <= 10 ))
# Out:
# False
